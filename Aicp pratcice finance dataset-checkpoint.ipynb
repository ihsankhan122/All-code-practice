# %%
# standard imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline  # show me here
# Out:
# UsageError: unrecognized arguments: # show me here

# %%
df=pd.read_csv("AICP_FinanceInsight_3.csv")
df
# Out:
#        Date_received                  Product  \
# 0          9/10/2013                 Mortgage
# 1         11/13/2014              Credit card
# 2          5/17/2012                 Mortgage
# 3          12/5/2012  Bank account or service
# 4           4/4/2016          Money transfers
# ...              ...                      ...
# 536473    10/19/2016                 Mortgage
# 536474     5/15/2012                 Mortgage
# 536475    11/10/2015              Credit card
# 536476     2/14/2013                 Mortgage
# 536477     6/24/2012                 Mortgage
#
#                                    Sub-product  \
# 0                               Other mortgage
# 1                                          NaN
# 2                               Other mortgage
# 3                   Other bank product/service
# 4                 Domestic (US) money transfer
# ...                                        ...
# 536473             Conventional fixed mortgage
# ...

# %%
df.head()
# Out:
#   Date_received                  Product                   Sub-product  \
# 0     9/10/2013                 Mortgage                Other mortgage
# 1    11/13/2014              Credit card                           NaN
# 2     5/17/2012                 Mortgage                Other mortgage
# 3     12/5/2012  Bank account or service    Other bank product/service
# 4      4/4/2016          Money transfers  Domestic (US) money transfer
#
#                                       Issue Sub-issue  \
# 0  Loan modification,collection,foreclosure       NaN
# 1                          Billing disputes       NaN
# 2  Loan modification,collection,foreclosure       NaN
# 3                  Deposits and withdrawals       NaN
# 4                             Fraud or scam       NaN
#
#   Consumer_complaint_narrative Company_public_response                Company  \
# 0                          NaN                     NaN  Wells Fargo & Company
# ...

# %%
df.columns
# Out:
# Index(['Date_received', 'Product', 'Sub-product', 'Issue', 'Sub-issue',
#        'Consumer_complaint_narrative', 'Company_public_response', 'Company',
#        'State', 'ZIP_code', 'Tags', 'Consumer_consent_provided?',
#        'Submitted_via', 'Date_sent_to_company', 'Company_response_to_consumer',
#        'Timely_response?', 'Consumer_disputed?', 'Complaint_ID',
#        'Industry_Risk', 'Resolution_Type', 'Transaction_Method',
#        'Communication_Channel', 'Satisfaction_Level', 'Customer_Type',
#        'Payment_Method', 'Contact_Channel', 'Resolution_Status',
#        'Feedback_Type'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Date_received                   object
# Product                         object
# Sub-product                     object
# Issue                           object
# Sub-issue                       object
# Consumer_complaint_narrative    object
# Company_public_response         object
# Company                         object
# State                           object
# ZIP_code                        object
# Tags                            object
# Consumer_consent_provided?      object
# Submitted_via                   object
# Date_sent_to_company            object
# Company_response_to_consumer    object
# Timely_response?                object
# Consumer_disputed?              object
# Complaint_ID                     int64
# Industry_Risk                   object
# Resolution_Type                 object
# Transaction_Method              object
# Communication_Channel           object
# Satisfaction_Level              object
# Customer_Type                   object
# ...

# %%
len(df)
# Out:
# 536478

# %%
# Separate the target variable (y) from the input features (x)
x = df['Complaint_ID']
y = df['Consumer_disputed?']

# %%
# Assuming 'x' is your DataFrame and 'Complaint_ID' is the column you want to convert to integers
x
#.astype('int')
# Out:
# 0          521213
# 1         1115104
# 2           80804
# 3          203948
# 4         1863588
#            ...
# 536473    2169466
# 536474      60363
# 536475    1648914
# 536476     316877
# 536477     107101
# Name: Complaint_ID, Length: 536478, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

# Assuming 'df' is your DataFrame and 'Customer Disputed' is the target variable
label_encoder = LabelEncoder()
df['Consumer_disputed?'] = label_encoder.fit_transform(df['Consumer_disputed?'])
import numpy as np

# %%
# Split the data into training and testing sets
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.30)

# %%
import numpy as np

# Assuming x_train and x_test are your feature matrices
# Reshape to 2D array if it's a single feature or a single sample
x_train_reshaped = np.array(x_train).reshape(-1, 1)
x_test_reshaped = np.array(x_test).reshape(-1, 1)

# Create and train the RandomForestClassifier model
from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier()
clf.fit(x_train_reshaped, y_train)

# Evaluate the model
accuracy = clf.score(x_test_reshaped, y_test)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.671245899194751
